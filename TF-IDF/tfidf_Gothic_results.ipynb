# %%
from wordcloud import WordCloud

# %%
# Features for American Gothic

# Top TF-IDF Nouns:
# Feature: time (Noun), TF-IDF Value: 2.9044
# Feature: man (Noun), TF-IDF Value: 2.5068
# Feature: day (Noun), TF-IDF Value: 2.1550
# Feature: eye (Noun), TF-IDF Value: 1.6506
# Feature: hand (Noun), TF-IDF Value: 1.2173
# Feature: head (Noun), TF-IDF Value: 1.2118
# Feature: heart (Noun), TF-IDF Value: 1.1811
# Feature: place (Noun), TF-IDF Value: 1.1739
# Feature: word (Noun), TF-IDF Value: 1.1478
# Feature: night (Noun), TF-IDF Value: 1.1453
# Feature: way (Noun), TF-IDF Value: 1.1339
# Feature: thing (Noun), TF-IDF Value: 1.1142
# Feature: country (Noun), TF-IDF Value: 1.0298
# Feature: year (Noun), TF-IDF Value: 1.0265
# Feature: life (Noun), TF-IDF Value: 0.9624
# Feature: world (Noun), TF-IDF Value: 0.9448
# Feature: mind (Noun), TF-IDF Value: 0.9408
# Feature: door (Noun), TF-IDF Value: 0.9148
# Feature: house (Noun), TF-IDF Value: 0.9085
# Feature: length (Noun), TF-IDF Value: 0.8682
# Feature: fact (Noun), TF-IDF Value: 0.8453
# Feature: squire (Noun), TF-IDF Value: 0.8395
# Feature: friend (Noun), TF-IDF Value: 0.8380
# Feature: foot (Noun), TF-IDF Value: 0.8379
# Feature: air (Noun), TF-IDF Value: 0.8345
# Feature: love (Noun), TF-IDF Value: 0.8152
# Feature: matter (Noun), TF-IDF Value: 0.7802
# Feature: family (Noun), TF-IDF Value: 0.7719
# Feature: idea (Noun), TF-IDF Value: 0.7538
# Feature: poem (Noun), TF-IDF Value: 0.7495
# Feature: work (Noun), TF-IDF Value: 0.7452
# Feature: manner (Noun), TF-IDF Value: 0.7428
# Feature: soul (Noun), TF-IDF Value: 0.7417
# Feature: lady (Noun), TF-IDF Value: 0.7384
# Feature: course (Noun), TF-IDF Value: 0.7383
# Feature: moment (Noun), TF-IDF Value: 0.7206
# Feature: point (Noun), TF-IDF Value: 0.7198
# Feature: water (Noun), TF-IDF Value: 0.7184
# Feature: tree (Noun), TF-IDF Value: 0.7055
# Feature: end (Noun), TF-IDF Value: 0.6991
# Feature: hour (Noun), TF-IDF Value: 0.6971
# Feature: spirit (Noun), TF-IDF Value: 0.6917
# Feature: illustration (Noun), TF-IDF Value: 0.6589
# Feature: kind (Noun), TF-IDF Value: 0.6582
# Feature: room (Noun), TF-IDF Value: 0.6521
# Feature: character (Noun), TF-IDF Value: 0.6453
# Feature: gentleman (Noun), TF-IDF Value: 0.6416
# Feature: book (Noun), TF-IDF Value: 0.6407
# Feature: death (Noun), TF-IDF Value: 0.6348
# Feature: light (Noun), TF-IDF Value: 0.6344
# preprocessed
# Top TF-IDF Adverbs:
# Feature: long (Adverb), TF-IDF Value: 4.1160
# Feature: far (Adverb), TF-IDF Value: 3.9961
# Feature: soon (Adverb), TF-IDF Value: 3.4985
# Feature: away (Adverb), TF-IDF Value: 3.1257
# Feature: immediately (Adverb), TF-IDF Value: 2.2600
# Feature: merely (Adverb), TF-IDF Value: 2.1596
# Feature: nearly (Adverb), TF-IDF Value: 2.0901
# Feature: forth (Adverb), TF-IDF Value: 1.9338
# Feature: altogether (Adverb), TF-IDF Value: 1.7003
# Feature: suddenly (Adverb), TF-IDF Value: 1.4548
# Feature: somewhat (Adverb), TF-IDF Value: 1.3976
# Feature: scarcely (Adverb), TF-IDF Value: 1.3902
# Feature: especially (Adverb), TF-IDF Value: 1.3875
# Feature: occasionally (Adverb), TF-IDF Value: 1.2587
# Feature: evidently (Adverb), TF-IDF Value: 1.2099
# Feature: generally (Adverb), TF-IDF Value: 1.2084
# Feature: home (Adverb), TF-IDF Value: 1.1627
# Feature: forward (Adverb), TF-IDF Value: 1.0887
# Feature: gradually (Adverb), TF-IDF Value: 1.0755
# Feature: afterward (Adverb), TF-IDF Value: 1.0645
# Feature: entirely (Adverb), TF-IDF Value: 1.0408
# Feature: particularly (Adverb), TF-IDF Value: 1.0283
# Feature: completely (Adverb), TF-IDF Value: 0.9720
# Feature: exceedingly (Adverb), TF-IDF Value: 0.9642
# Feature: nevermore (Adverb), TF-IDF Value: 0.9414
# Feature: accordingly (Adverb), TF-IDF Value: 0.9298
# Feature: well (Adverb), TF-IDF Value: 0.9201
# Feature: kind (Adverb), TF-IDF Value: 0.9190
# Feature: precisely (Adverb), TF-IDF Value: 0.9017
# Feature: truly (Adverb), TF-IDF Value: 0.8903
# Feature: certainly (Adverb), TF-IDF Value: 0.8892
# Feature: easily (Adverb), TF-IDF Value: 0.8739
# Feature: probably (Adverb), TF-IDF Value: 0.8703
# Feature: absolutely (Adverb), TF-IDF Value: 0.8697
# Feature: finally (Adverb), TF-IDF Value: 0.8472
# Feature: actually (Adverb), TF-IDF Value: 0.8311
# Feature: apparently (Adverb), TF-IDF Value: 0.8285
# Feature: ago (Adverb), TF-IDF Value: 0.8213
# Feature: fully (Adverb), TF-IDF Value: 0.8120
# Feature: surely (Adverb), TF-IDF Value: 0.7818
# Feature: sufficiently (Adverb), TF-IDF Value: 0.7813
# Feature: instead (Adverb), TF-IDF Value: 0.7748
# Feature: partly (Adverb), TF-IDF Value: 0.7572
# Feature: perfectly (Adverb), TF-IDF Value: 0.7419
# Feature: frequently (Adverb), TF-IDF Value: 0.7340
# Feature: close (Adverb), TF-IDF Value: 0.7215
# Feature: continually (Adverb), TF-IDF Value: 0.7041
# Feature: thoroughly (Adverb), TF-IDF Value: 0.7026
# Feature: distinctly (Adverb), TF-IDF Value: 0.6953
# Feature: utterly (Adverb), TF-IDF Value: 0.6916
# preprocessed
# Top TF-IDF Verbs:
# Feature: find (Verb), TF-IDF Value: 4.2782
# Feature: come (Verb), TF-IDF Value: 3.6569
# Feature: know (Verb), TF-IDF Value: 3.3191
# Feature: think (Verb), TF-IDF Value: 3.0099
# Feature: look (Verb), TF-IDF Value: 2.5496
# Feature: lie (Verb), TF-IDF Value: 2.0458
# Feature: hear (Verb), TF-IDF Value: 2.0170
# Feature: let (Verb), TF-IDF Value: 1.9428
# Feature: tell (Verb), TF-IDF Value: 1.9041
# Feature: leave (Verb), TF-IDF Value: 1.8707
# Feature: feel (Verb), TF-IDF Value: 1.8483
# Feature: bring (Verb), TF-IDF Value: 1.8230
# Feature: appear (Verb), TF-IDF Value: 1.6722
# Feature: pass (Verb), TF-IDF Value: 1.6387
# Feature: speak (Verb), TF-IDF Value: 1.5712
# Feature: turn (Verb), TF-IDF Value: 1.5280
# Feature: fall (Verb), TF-IDF Value: 1.4818
# Feature: stand (Verb), TF-IDF Value: 1.4017
# Feature: throw (Verb), TF-IDF Value: 1.3719
# Feature: grow (Verb), TF-IDF Value: 1.2483
# Feature: see (Verb), TF-IDF Value: 1.2364
# Feature: sit (Verb), TF-IDF Value: 1.2159
# Feature: consider (Verb), TF-IDF Value: 1.2113
# Feature: hold (Verb), TF-IDF Value: 1.1770
# Feature: suppose (Verb), TF-IDF Value: 1.1470
# Feature: set (Verb), TF-IDF Value: 1.1459
# Feature: remain (Verb), TF-IDF Value: 1.1241
# Feature: write (Verb), TF-IDF Value: 1.1034
# Feature: observe (Verb), TF-IDF Value: 1.0791
# Feature: begin (Verb), TF-IDF Value: 1.0359
# Feature: receive (Verb), TF-IDF Value: 1.0241
# Feature: enter (Verb), TF-IDF Value: 0.9953
# Feature: meet (Verb), TF-IDF Value: 0.9872
# Feature: hang (Verb), TF-IDF Value: 0.9424
# Feature: believe (Verb), TF-IDF Value: 0.9423
# Feature: draw (Verb), TF-IDF Value: 0.9361
# Feature: carry (Verb), TF-IDF Value: 0.9222
# Feature: live (Verb), TF-IDF Value: 0.9132
# Feature: continue (Verb), TF-IDF Value: 0.8943
# Feature: read (Verb), TF-IDF Value: 0.8880
# Feature: understand (Verb), TF-IDF Value: 0.8867
# Feature: follow (Verb), TF-IDF Value: 0.8587
# Feature: send (Verb), TF-IDF Value: 0.8513
# Feature: return (Verb), TF-IDF Value: 0.8444
# Feature: bear (Verb), TF-IDF Value: 0.8424
# Feature: break (Verb), TF-IDF Value: 0.8391
# Feature: reach (Verb), TF-IDF Value: 0.8387
# Feature: run (Verb), TF-IDF Value: 0.7890
# Feature: discover (Verb), TF-IDF Value: 0.7883
# Feature: die (Verb), TF-IDF Value: 0.7865
# preprocessed
# Top TF-IDF Adjectives:
# Feature: great (Adjective), TF-IDF Value: 4.9728
# Feature: old (Adjective), TF-IDF Value: 4.7031
# Feature: little (Adjective), TF-IDF Value: 3.9306
# Feature: good (Adjective), TF-IDF Value: 3.3000
# Feature: long (Adjective), TF-IDF Value: 1.8632
# Feature: young (Adjective), TF-IDF Value: 1.6287
# Feature: high (Adjective), TF-IDF Value: 1.3840
# Feature: present (Adjective), TF-IDF Value: 1.3836
# Feature: large (Adjective), TF-IDF Value: 1.3518
# Feature: small (Adjective), TF-IDF Value: 1.3055
# Feature: true (Adjective), TF-IDF Value: 1.2822
# Feature: new (Adjective), TF-IDF Value: 1.2588
# Feature: general (Adjective), TF-IDF Value: 1.2050
# Feature: open (Adjective), TF-IDF Value: 1.0799
# Feature: poor (Adjective), TF-IDF Value: 1.0310
# Feature: certain (Adjective), TF-IDF Value: 1.0024
# Feature: mere (Adjective), TF-IDF Value: 0.9736
# Feature: wild (Adjective), TF-IDF Value: 0.9652
# Feature: ancient (Adjective), TF-IDF Value: 0.9348
# Feature: black (Adjective), TF-IDF Value: 0.8738
# Feature: beautiful (Adjective), TF-IDF Value: 0.8542
# Feature: sure (Adjective), TF-IDF Value: 0.8362
# Feature: possible (Adjective), TF-IDF Value: 0.8349
# Feature: early (Adjective), TF-IDF Value: 0.8241
# Feature: low (Adjective), TF-IDF Value: 0.8223
# Feature: deep (Adjective), TF-IDF Value: 0.8151
# Feature: happy (Adjective), TF-IDF Value: 0.7555
# Feature: fine (Adjective), TF-IDF Value: 0.7505
# Feature: short (Adjective), TF-IDF Value: 0.7425
# Feature: second (Adjective), TF-IDF Value: 0.7307
# Feature: human (Adjective), TF-IDF Value: 0.7237
# Feature: fair (Adjective), TF-IDF Value: 0.7095
# Feature: white (Adjective), TF-IDF Value: 0.6858
# Feature: worthy (Adjective), TF-IDF Value: 0.6755
# Feature: right (Adjective), TF-IDF Value: 0.6742
# Feature: dutch (Adjective), TF-IDF Value: 0.6659
# Feature: late (Adjective), TF-IDF Value: 0.6420
# Feature: usual (Adjective), TF-IDF Value: 0.6373
# Feature: dead (Adjective), TF-IDF Value: 0.6273
# Feature: dark (Adjective), TF-IDF Value: 0.6143
# Feature: strong (Adjective), TF-IDF Value: 0.6104
# Feature: strange (Adjective), TF-IDF Value: 0.6086
# Feature: natural (Adjective), TF-IDF Value: 0.6056
# Feature: simple (Adjective), TF-IDF Value: 0.5962
# Feature: dear (Adjective), TF-IDF Value: 0.5917
# Feature: vast (Adjective), TF-IDF Value: 0.5812
# Feature: rich (Adjective), TF-IDF Value: 0.5804
# Feature: sweet (Adjective), TF-IDF Value: 0.5802
# Feature: green (Adjective), TF-IDF Value: 0.5681
# Feature: impossible (Adjective), TF-IDF Value: 0.5670
# preprocessed
# Top Words by TF-IDF Score for the Entire Corpus:
# the: 10.4073
# of: 6.4381
# be: 4.9045
# and: 4.7968
# to: 3.4077
# in: 2.9319
# have: 1.9023
# his: 1.6160
# that: 1.5720
# with: 1.3917
# he: 1.3557
# it: 1.3502
# as: 1.1043
# at: 0.9632
# by: 0.9566
# which: 0.9440
# for: 0.9438
# this: 0.7682
# but: 0.7621
# my: 0.7370
# from: 0.7360
# on: 0.7239
# not: 0.6946
# all: 0.6322
# an: 0.5370
# or: 0.5245
# one: 0.4943
# we: 0.4887
# their: 0.4542
# upon: 0.4508
# him: 0.4435
# no: 0.4178
# her: 0.4126
# so: 0.4116
# they: 0.4112
# me: 0.4066
# its: 0.3662
# say: 0.3526
# there: 0.3514
# who: 0.3490
# more: 0.3355
# some: 0.3311
# make: 0.3208
# when: 0.3105
# do: 0.3018
# you: 0.2923
# would: 0.2896
# time: 0.2868
# now: 0.2863
# into: 0.2861

# %%
# GENERAL
feature_names = [
    "time", "man", "day", "eye", "hand",
    "head", "heart", "place", "word", "night",
    "way", "thing", "country", "year", "life",
    "world", "mind", "door", "house", "length",
    "fact", "squire", "friend", "foot", "air",
    "love", "matter", "family", "idea", "poem",
    "work", "manner", "soul", "lady", "course",
    "moment", "point", "water", "tree", "end",
    "hour", "spirit", "illustration", "kind", "room"
]

tfidf_values = [
    2.5129, 2.2112, 1.9887, 1.7126, 1.5262,
    1.4798, 1.3611, 1.2260, 1.1977, 1.1750,
    1.1611, 1.1524, 1.0898, 1.0313, 0.9599,
    0.9387, 0.8999, 0.8963, 0.8603, 0.8353,
    0.7997, 0.7316, 0.7277, 0.7190, 0.7089,
    0.7002, 0.7001, 0.6963, 0.6960, 0.6930,
    0.6926, 0.6760, 0.6518, 0.6510, 0.6489,
    0.6409, 0.6377, 0.6335, 0.6333, 0.6282,
    0.6221, 0.6202, 0.6186, 0.6177, 0.6057,
    0.5999, 0.5958, 0.5942, 0.5925, 0.5902,
    0.5859, 0.5700, 0.5637, 0.5611, 0.5558,
    0.5467, 0.5453, 0.5446, 0.5415, 0.5402,
    0.5379, 0.5314, 0.5302, 0.5298, 0.5234,
    0.5189, 0.5176, 0.5174, 0.5115, 0.5109,
    0.5096, 0.5088, 0.5065, 0.5064, 0.5001,
    0.4943, 0.4899, 0.4894, 0.4847, 0.4742,
    0.4697, 0.4690, 0.4658, 0.4633, 0.4577,
    0.4549, 0.4509, 0.4480, 0.4471, 0.4465,
    0.4461, 0.4453, 0.4438, 0.4382, 0.4378,
    0.4373, 0.4323, 0.4315, 0.4307, 0.4287
]

print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names, tfidf_values):
    print("{:<20} {:<15.4f}".format(feature, tfidf))
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# time                 2.5129
# man                  2.2112
# day                  1.9887
# eye                  1.7126
# hand                 1.5262
# head                 1.4798
# heart                1.3611
# place                1.2260
# word                 1.1977
# night                1.1750
# way                  1.1611
# thing                1.1524
# country              1.0898
# year                 1.0313
# life                 0.9599
# world                0.9387
# mind                 0.8999
# door                 0.8963
# house                0.8603
# length               0.8353
# fact                 0.7997
# squire               0.7316
# friend               0.7277
# foot                 0.7190
# air                  0.7089
# love                 0.7002
# matter               0.7001
# family               0.6963
# idea                 0.6960
# poem                 0.6930
# ...

# %%
# NOUNS
feature_names = [
    "time", "man", "day", "eye", "hand",
    "head", "heart", "place", "word", "night",
    "way", "thing", "country", "year", "life",
    "world", "mind", "door", "house", "length",
    "fact", "squire", "friend", "foot", "air",
    "love", "matter", "family", "idea", "poem",
    "work", "manner", "soul", "lady", "course",
    "moment", "point", "water", "tree", "end",
    "hour", "spirit", "illustration", "kind", "room",
    "character", "gentleman", "book", "death", "light",
    "nature", "poet", "body", "face", "person",
    "state", "earth", "goldsmith", "beauty", "effect",
    "arm", "land", "sea", "mean", "voice",
    "city", "wind", "morning", "power", "scene",
    "question", "line", "form", "truth", "people",
    "story", "dream", "window", "case", "village",
    "chamber", "hall", "fire", "object", "abbey",
    "sound", "horse", "appearance", "letter", "star",
    "reason", "wall", "account", "king", "degree",
    "circumstance", "law", "distance", "sun", "island"
]

tfidf_values = [
    2.9044, 2.5068, 2.1550, 1.6506, 1.2173,
    1.2118, 1.1811, 1.1739, 1.1478, 1.1453,
    1.1339, 1.1142, 1.0298, 1.0265, 0.9624,
    0.9448, 0.9408, 0.9148, 0.9085, 0.8682,
    0.8453, 0.8395, 0.8380, 0.8379, 0.8345,
    0.8152, 0.7802, 0.7719, 0.7538, 0.7495,
    0.7452, 0.7428, 0.7417, 0.7384, 0.7383,
    0.7206, 0.7198, 0.7184, 0.7055, 0.6991,
    0.6971, 0.6917, 0.6589, 0.6582, 0.6521,
    0.6453, 0.6416, 0.6407, 0.6348, 0.6344,
    0.6313, 0.6258, 0.6157, 0.6128, 0.6087,
    0.5789, 0.5733, 0.5711, 0.5698, 0.5621,
    0.5556, 0.5539, 0.5531, 0.5523, 0.5521,
    0.5498, 0.5333, 0.5313, 0.5221, 0.5156,
    0.5140, 0.5137, 0.5116, 0.5107, 0.5065,
    0.5051, 0.5045, 0.5039, 0.5010, 0.5002,
    0.4992, 0.4958, 0.4834, 0.4826, 0.4810,
    0.4809, 0.4803, 0.4757, 0.4753, 0.4747,
    0.4702, 0.4618, 0.4547, 0.4511, 0.4465,
    0.4453, 0.4429, 0.4341, 0.4291, 0.4284
]

print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names, tfidf_values):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))


wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names, tfidf_values)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: time        2.9044
# Feature: man         2.5068
# Feature: day         2.1550
# Feature: eye         1.6506
# Feature: hand        1.2173
# Feature: head        1.2118
# Feature: heart       1.1811
# Feature: place       1.1739
# Feature: word        1.1478
# Feature: night       1.1453
# Feature: way         1.1339
# Feature: thing       1.1142
# Feature: country     1.0298
# Feature: year        1.0265
# Feature: life        0.9624
# Feature: world       0.9448
# Feature: mind        0.9408
# Feature: door        0.9148
# Feature: house       0.9085
# Feature: length      0.8682
# Feature: fact        0.8453
# Feature: squire      0.8395
# Feature: friend      0.8380
# Feature: foot        0.8379
# Feature: air         0.8345
# Feature: love        0.8152
# Feature: matter      0.7802
# Feature: family      0.7719
# Feature: idea        0.7538
# Feature: poem        0.7495
# ...

# %%
# ADVERBS
feature_names2 = [
    "long", "far", "soon", "away", "immediately",
    "merely", "nearly", "forth", "altogether", "suddenly",
    "somewhat", "scarcely", "especially", "occasionally", "evidently",
    "generally", "home", "forward", "gradually", "afterward",
    "entirely", "particularly", "completely", "exceedingly", "nevermore",
    "accordingly", "well", "kind", "precisely", "truly",
    "certainly", "easily", "probably", "absolutely", "finally",
    "actually", "apparently", "ago", "fully", "surely",
    "sufficiently", "instead", "partly", "perfectly", "frequently",
    "close", "continually", "thoroughly", "distinctly", "utterly",
    "slowly", "doubt", "readily", "equally", "extremely",
    "carefully", "ichabod", "simply", "greatly", "deeply",
    "properly", "directly", "forever", "pretty", "round",
    "quietly", "hard", "clearly", "highly", "little",
    "recently", "presently", "seldom", "aside", "originally",
    "half", "likewise", "rapidly", "commonly", "shortly",
    "early", "usually", "lately", "fast", "naturally",
    "gently", "abroad", "consequently", "right", "fairly",
    "closely", "possibly", "undoubtedly", "excessively", "chiefly",
    "rarely", "apart", "instantly", "exactly", "slightly"
]

tfidf_values2 = [
    4.1160, 3.9961, 3.4985, 3.1257, 2.2600,
    2.1596, 2.0901, 1.9338, 1.7003, 1.4548,
    1.3976, 1.3902, 1.3875, 1.2587, 1.2099,
    1.2084, 1.1627, 1.0887, 1.0755, 1.0645,
    1.0408, 1.0283, 0.9720, 0.9642, 0.9414,
    0.9298, 0.9201, 0.9190, 0.9017, 0.8903,
    0.8892, 0.8739, 0.8703, 0.8697, 0.8472,
    0.8311, 0.8285, 0.8213, 0.8120, 0.7818,
    0.7813, 0.7748, 0.7572, 0.7419, 0.7340,
    0.7215, 0.7041, 0.7026, 0.6953, 0.6916,
    0.6683, 0.6649, 0.6571, 0.6426, 0.6365,
    0.6295, 0.6148, 0.6096, 0.6081, 0.6071,
    0.6005, 0.5961, 0.5906, 0.5903, 0.5862,
    0.5785, 0.5739, 0.5626, 0.5590, 0.5567,
    0.5508, 0.5480, 0.5445, 0.5360, 0.5336,
    0.5235, 0.5228, 0.5186, 0.5153, 0.5129,
    0.5014, 0.4980, 0.4933, 0.4866, 0.4754,
    0.4651, 0.4630, 0.4607, 0.4585, 0.4584,
    0.4447, 0.4411, 0.4393, 0.4374, 0.4345,
    0.4227, 0.4211, 0.4191, 0.4157, 0.4108
]

print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names2, tfidf_values2):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names2, tfidf_values2)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: long        4.1160
# Feature: far         3.9961
# Feature: soon        3.4985
# Feature: away        3.1257
# Feature: immediately 2.2600
# Feature: merely      2.1596
# Feature: nearly      2.0901
# Feature: forth       1.9338
# Feature: altogether  1.7003
# Feature: suddenly    1.4548
# Feature: somewhat    1.3976
# Feature: scarcely    1.3902
# Feature: especially  1.3875
# Feature: occasionally 1.2587
# Feature: evidently   1.2099
# Feature: generally   1.2084
# Feature: home        1.1627
# Feature: forward     1.0887
# Feature: gradually   1.0755
# Feature: afterward   1.0645
# Feature: entirely    1.0408
# Feature: particularly 1.0283
# Feature: completely  0.9720
# Feature: exceedingly 0.9642
# Feature: nevermore   0.9414
# Feature: accordingly 0.9298
# Feature: well        0.9201
# Feature: kind        0.9190
# Feature: precisely   0.9017
# Feature: truly       0.8903
# ...

# %%
# VERBS
feature_names_verbs = [
    "find", "come", "know", "think", "look",
    "lie", "hear", "let", "tell", "leave",
    "feel", "bring", "appear", "pass", "speak",
    "turn", "fall", "stand", "throw", "grow",
    "see", "sit", "consider", "hold", "suppose",
    "set", "remain", "write", "observe", "begin",
    "receive", "enter", "meet", "hang", "believe",
    "draw", "carry", "live", "continue", "read",
    "understand", "follow", "send", "return", "bear",
    "break", "reach", "run", "discover", "die",
    "proceed", "forget", "arise", "seek", "exist",
    "mean", "use", "fly", "lead", "form",
    "behold", "wear", "prove", "lose", "remember",
    "perceive", "render", "play", "pay", "regard",
    "walk", "ask", "mention", "maintain", "suffer",
    "learn", "love", "cut", "add", "admit",
    "wish", "serve", "suggest", "sing", "fail",
    "arrive", "fill", "reply", "produce", "attend",
    "listen", "imagine", "drive", "determine", "prepare",
    "rise", "afford", "expect", "conceive", "talk"
]

tfidf_values_verbs = [
    4.2782, 3.6569, 3.3191, 3.0099, 2.5496,
    2.0458, 2.0170, 1.9428, 1.9041, 1.8707,
    1.8483, 1.8230, 1.6722, 1.6387, 1.5712,
    1.5280, 1.4818, 1.4017, 1.3719, 1.2483,
    1.2364, 1.2159, 1.2113, 1.1770, 1.1470,
    1.1459, 1.1241, 1.1034, 1.0791, 1.0359,
    1.0241, 0.9953, 0.9872, 0.9424, 0.9423,
    0.9361, 0.9222, 0.9132, 0.8943, 0.8880,
    0.8867, 0.8587, 0.8513, 0.8444, 0.8424,
    0.8391, 0.8387, 0.7890, 0.7883, 0.7865,
    0.7524, 0.7488, 0.7341, 0.7166, 0.7147,
    0.6942, 0.6875, 0.6725, 0.6686, 0.6669,
    0.6576, 0.6334, 0.6083, 0.6044, 0.6036,
    0.6024, 0.5989, 0.5940, 0.5934, 0.5792,
    0.5645, 0.5553, 0.5518, 0.5472, 0.5412,
    0.5327, 0.5243, 0.5212, 0.5094, 0.5067,
    0.5059, 0.5038, 0.5016, 0.4943, 0.4942,
    0.4937, 0.4927, 0.4885, 0.4828, 0.4773,
    0.4772, 0.4663, 0.4629, 0.4620, 0.4617,
    0.4605, 0.4555, 0.4490, 0.4471, 0.4331,
]

print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names_verbs, tfidf_values_verbs):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names_verbs, tfidf_values_verbs)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: find        4.2782
# Feature: come        3.6569
# Feature: know        3.3191
# Feature: think       3.0099
# Feature: look        2.5496
# Feature: lie         2.0458
# Feature: hear        2.0170
# Feature: let         1.9428
# Feature: tell        1.9041
# Feature: leave       1.8707
# Feature: feel        1.8483
# Feature: bring       1.8230
# Feature: appear      1.6722
# Feature: pass        1.6387
# Feature: speak       1.5712
# Feature: turn        1.5280
# Feature: fall        1.4818
# Feature: stand       1.4017
# Feature: throw       1.3719
# Feature: grow        1.2483
# Feature: see         1.2364
# Feature: sit         1.2159
# Feature: consider    1.2113
# Feature: hold        1.1770
# Feature: suppose     1.1470
# Feature: set         1.1459
# Feature: remain      1.1241
# Feature: write       1.1034
# Feature: observe     1.0791
# Feature: begin       1.0359
# ...

# %%
# ADJECTIVES
feature_names_adjectives = [
    "great", "old", "little", "good", "long",
    "young", "high", "present", "large", "small",
    "true", "new", "general", "open", "poor",
    "certain", "mere", "wild", "ancient", "black",
    "beautiful", "sure", "possible", "early", "low",
    "deep", "happy", "fine", "short", "second",
    "human", "fair", "white", "worthy", "right",
    "dutch", "late", "usual", "dead", "dark",
    "strong", "strange", "natural", "simple", "dear",
    "vast", "rich", "sweet", "green", "impossible",
    "similar", "necessary", "ill", "proper", "common",
    "ready", "single", "particular", "public", "different",
    "able", "fancy", "lenore", "clear", "sleepy",
    "red", "english", "slight", "original", "bright",
    "peculiar", "huge", "favorite", "literary", "close",
    "light", "well", "distant", "sad", "half",
    "modern", "perfect", "ordinary", "gentle", "sufficient",
    "broad", "absolute", "singular", "bad", "complete",
    "noble", "wide", "quiet", "real", "remarkable",
    "grand", "melancholy", "evident", "french", "apparent"
]

tfidf_values_adjectives = [
    4.9728, 4.7031, 3.9306, 3.3000, 1.8632,
    1.6287, 1.3840, 1.3836, 1.3518, 1.3055,
    1.2822, 1.2588, 1.2050, 1.0799, 1.0310,
    1.0024, 0.9736, 0.9652, 0.9348, 0.8738,
    0.8542, 0.8362, 0.8349, 0.8241, 0.8223,
    0.8151, 0.7555, 0.7505, 0.7425, 0.7307,
    0.7237, 0.7095, 0.6858, 0.6755, 0.6742,
    0.6659, 0.6420, 0.6373, 0.6273, 0.6143,
    0.6104, 0.6086, 0.6056, 0.5962, 0.5917,
    0.5812, 0.5804, 0.5802, 0.5681, 0.5670,
    0.5599, 0.5591, 0.5499, 0.5469, 0.5461,
    0.5406, 0.5231, 0.5213, 0.5139, 0.5123,
    0.5046, 0.5022, 0.5014, 0.4974, 0.4919,
    0.4873, 0.4869, 0.4841, 0.4818, 0.4815,
    0.4790, 0.4755, 0.4736, 0.4731, 0.4703,
    0.4663, 0.4660, 0.4611, 0.4571, 0.4464,
    0.4433, 0.4385, 0.4383, 0.4375, 0.4372,
    0.4364, 0.4350, 0.4349, 0.4345, 0.4240,
    0.4225, 0.4195, 0.4120, 0.4090, 0.4085,
    0.4082, 0.4080, 0.4045, 0.3992, 0.3969
]

print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names_adjectives, tfidf_values_adjectives):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names_adjectives, tfidf_values_adjectives)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: great       4.9728
# Feature: old         4.7031
# Feature: little      3.9306
# Feature: good        3.3000
# Feature: long        1.8632
# Feature: young       1.6287
# Feature: high        1.3840
# Feature: present     1.3836
# Feature: large       1.3518
# Feature: small       1.3055
# Feature: true        1.2822
# Feature: new         1.2588
# Feature: general     1.2050
# Feature: open        1.0799
# Feature: poor        1.0310
# Feature: certain     1.0024
# Feature: mere        0.9736
# Feature: wild        0.9652
# Feature: ancient     0.9348
# Feature: black       0.8738
# Feature: beautiful   0.8542
# Feature: sure        0.8362
# Feature: possible    0.8349
# Feature: early       0.8241
# Feature: low         0.8223
# Feature: deep        0.8151
# Feature: happy       0.7555
# Feature: fine        0.7505
# Feature: short       0.7425
# Feature: second      0.7307
# ...
