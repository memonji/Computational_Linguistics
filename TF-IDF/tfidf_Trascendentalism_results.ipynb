# %%
from wordcloud import WordCloud

# %%
# NOUNS
# Define the feature names and TF-IDF values as lists
import matplotlib.pyplot as plt

# Define the feature names and TF-IDF values as lists
feature_names = [
    "man", "time", "day", "tree", "apple",
    "life", "wood", "water", "river", "night",
    "way", "lake", "mile", "year", "foot",
    "hand", "shore", "land", "place", "nature",
    "soul", "canoe", "thing", "earth", "house",
    "fruit", "eye", "indian", "word", "state",
    "stream", "world", "sun", "wind", "mountain",
    "work", "light", "sea", "head", "rock",
    "forest", "hour", "morning", "sound", "body",
    "country", "captain", "death", "ship", "air",
    "boat", "fire", "bird", "grind", "leave",
    "war", "moose", "field", "poet", "fall",
    "friend", "love", "face", "island", "music",
    "camp", "poem", "government", "law", "end",
    "grass", "age", "star", "point", "city",
    "sight", "rest", "woman", "length", "fish",
    "companion", "mind", "form", "summer", "spring",
    "book", "color", "bank", "heart", "winter",
    "soldier", "course", "rod", "spirit", "sense",
    "road", "hill", "child", "town", "sky"
]

tfidf_values = [
    2.9779, 1.4152, 1.3947, 1.2567, 1.0909,
    0.9095, 0.9077, 0.9060, 0.8284, 0.8230,
    0.7425, 0.7281, 0.7268, 0.7226, 0.6789,
    0.6612, 0.6314, 0.6294, 0.6217, 0.6005,
    0.5962, 0.5952, 0.5905, 0.5653, 0.5265,
    0.5149, 0.5047, 0.4992, 0.4945, 0.4930,
    0.4924, 0.4922, 0.4865, 0.4841, 0.4789,
    0.4703, 0.4628, 0.4423, 0.4417, 0.4223,
    0.4199, 0.4148, 0.4039, 0.4026, 0.3994,
    0.3952, 0.3952, 0.3893, 0.3872, 0.3850,
    0.3836, 0.3834, 0.3790, 0.3759, 0.3713,
    0.3685, 0.3672, 0.3642, 0.3559, 0.3518,
    0.3479, 0.3460, 0.3449, 0.3407, 0.3365,
    0.3362, 0.3308, 0.3283, 0.3278, 0.3239,
    0.3228, 0.3192, 0.3178, 0.3178, 0.3034,
    0.2964, 0.2869, 0.2855, 0.2839, 0.2813,
    0.2809, 0.2797, 0.2786, 0.2779, 0.2657,
    0.2648, 0.2647, 0.2643, 0.2627, 0.2582,
    0.2558, 0.2550, 0.2536, 0.2528, 0.2496,
    0.2494, 0.2491, 0.2477, 0.2465, 0.2443
]

# Create the table
print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names, tfidf_values):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names, tfidf_values)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: man         2.9779
# Feature: time        1.4152
# Feature: day         1.3947
# Feature: tree        1.2567
# Feature: apple       1.0909
# Feature: life        0.9095
# Feature: wood        0.9077
# Feature: water       0.9060
# Feature: river       0.8284
# Feature: night       0.8230
# Feature: way         0.7425
# Feature: lake        0.7281
# Feature: mile        0.7268
# Feature: year        0.7226
# Feature: foot        0.6789
# Feature: hand        0.6612
# Feature: shore       0.6314
# Feature: land        0.6294
# Feature: place       0.6217
# Feature: nature      0.6005
# Feature: soul        0.5962
# Feature: canoe       0.5952
# Feature: thing       0.5905
# Feature: earth       0.5653
# Feature: house       0.5265
# Feature: fruit       0.5149
# Feature: eye         0.5047
# Feature: indian      0.4992
# Feature: word        0.4945
# Feature: state       0.4930
# ...

# %%
# ADVERBS
# Define the feature names and TF-IDF values as lists
import matplotlib.pyplot as plt

# Define the feature names and TF-IDF values as lists
feature_names = [
    "far", "long", "away", "soon", "commonly",
    "well", "probably", "perchance", "generally", "merely",
    "forth", "especially", "hardly", "frequently", "ago",
    "close", "occasionally", "forward", "somewhat", "near",
    "surely", "instead", "suddenly", "apparently", "nearly",
    "early", "right", "perfectly", "easily", "home",
    "equally", "round", "sort", "slowly", "chiefly",
    "partly", "entirely", "rapidly", "lately", "fast",
    "forever", "afterward", "wholly", "finally", "pretty",
    "directly", "fairly", "late", "doubt", "infinitely",
    "regularly", "simply", "certainly", "exactly", "truly",
    "hard", "fully", "gradually", "onward", "aside",
    "immediately", "steadily", "comparatively", "silently", "altogether",
    "half", "particularly", "incessantly", "deeply", "gently",
    "naturally", "twice", "later", "upward", "straight",
    "swiftly", "bartleby", "evidently", "annually", "abroad",
    "possibly", "thickly", "henceforth", "continually", "implicitly",
    "ahead", "kind", "mainly", "rarely", "justly",
    "little", "north", "deep", "westward", "distinctly",
    "accordingly", "safely", "quickly", "curiously", "recently"
]

tfidf_values = [
    3.7775, 2.9920, 1.9398, 1.8843, 1.2162,
    1.0854, 1.0325, 0.9862, 0.8986, 0.8710,
    0.8680, 0.7764, 0.7315, 0.7026, 0.6940,
    0.6887, 0.6873, 0.6737, 0.6728, 0.6441,
    0.6268, 0.6226, 0.6014, 0.5990, 0.5915,
    0.5860, 0.5581, 0.5522, 0.5484, 0.5314,
    0.5203, 0.5193, 0.5114, 0.5026, 0.4956,
    0.4923, 0.4778, 0.4655, 0.4624, 0.4611,
    0.4535, 0.4528, 0.4462, 0.4295, 0.4249,
    0.4104, 0.4104, 0.4066, 0.4006, 0.3985,
    0.3864, 0.3842, 0.3773, 0.3765, 0.3760,
    0.3757, 0.3736, 0.3671, 0.3631, 0.3592,
    0.3559, 0.3537, 0.3534, 0.3529, 0.3515,
    0.3471, 0.3454, 0.3341, 0.3319, 0.3313,
    0.3267, 0.3252, 0.3246, 0.3230, 0.3200,
    0.3088, 0.3086, 0.3046, 0.2977, 0.2899,
    0.2890, 0.2854, 0.2846, 0.2841, 0.2808,
    0.2791, 0.2770, 0.2751, 0.2700, 0.2696,
    0.2655, 0.2632, 0.2629, 0.2556, 0.2536,
    0.2505, 0.2482, 0.2476, 0.2451, 0.2392
]

# Create the table
print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names, tfidf_values):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names, tfidf_values)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: far         3.7775
# Feature: long        2.9920
# Feature: away        1.9398
# Feature: soon        1.8843
# Feature: commonly    1.2162
# Feature: well        1.0854
# Feature: probably    1.0325
# Feature: perchance   0.9862
# Feature: generally   0.8986
# Feature: merely      0.8710
# Feature: forth       0.8680
# Feature: especially  0.7764
# Feature: hardly      0.7315
# Feature: frequently  0.7026
# Feature: ago         0.6940
# Feature: close       0.6887
# Feature: occasionally 0.6873
# Feature: forward     0.6737
# Feature: somewhat    0.6728
# Feature: near        0.6441
# Feature: surely      0.6268
# Feature: instead     0.6226
# Feature: suddenly    0.6014
# Feature: apparently  0.5990
# Feature: nearly      0.5915
# Feature: early       0.5860
# Feature: right       0.5581
# Feature: perfectly   0.5522
# Feature: easily      0.5484
# Feature: home        0.5314
# ...

# %%
# ADVERBS
# Define the feature names and TF-IDF values as lists
import matplotlib.pyplot as plt

# Define the feature names and TF-IDF values as lists
feature_names = [
    "far", "long", "away", "soon", "commonly",
    "well", "probably", "perchance", "generally", "merely",
    "forth", "especially", "hardly", "frequently", "ago",
    "close", "occasionally", "forward", "somewhat", "near",
    "surely", "instead", "suddenly", "apparently", "nearly",
    "early", "right", "perfectly", "easily", "home",
    "equally", "round", "sort", "slowly", "chiefly",
    "partly", "entirely", "rapidly", "lately", "fast",
    "forever", "afterward", "wholly", "finally", "pretty",
    "directly", "fairly", "late", "doubt", "infinitely",
    "regularly", "simply", "certainly", "exactly", "truly",
    "hard", "fully", "gradually", "onward", "aside",
    "immediately", "steadily", "comparatively", "silently", "altogether",
    "half", "particularly", "incessantly", "deeply", "gently",
    "naturally", "twice", "later", "upward", "straight",
    "swiftly", "bartleby", "evidently", "annually", "abroad",
    "possibly", "thickly", "henceforth", "continually", "implicitly",
    "ahead", "kind", "mainly", "rarely", "justly",
    "little", "north", "deep", "westward", "distinctly",
    "accordingly", "safely", "quickly", "curiously", "recently"
]

tfidf_values = [
    3.7775, 2.9920, 1.9398, 1.8843, 1.2162,
    1.0854, 1.0325, 0.9862, 0.8986, 0.8710,
    0.8680, 0.7764, 0.7315, 0.7026, 0.6940,
    0.6887, 0.6873, 0.6737, 0.6728, 0.6441,
    0.6268, 0.6226, 0.6014, 0.5990, 0.5915,
    0.5860, 0.5581, 0.5522, 0.5484, 0.5314,
    0.5203, 0.5193, 0.5114, 0.5026, 0.4956,
    0.4923, 0.4778, 0.4655, 0.4624, 0.4611,
    0.4535, 0.4528, 0.4462, 0.4295, 0.4249,
    0.4104, 0.4104, 0.4066, 0.4006, 0.3985,
    0.3864, 0.3842, 0.3773, 0.3765, 0.3760,
    0.3757, 0.3736, 0.3671, 0.3631, 0.3592,
    0.3559, 0.3537, 0.3534, 0.3529, 0.3515,
    0.3471, 0.3454, 0.3341, 0.3319, 0.3313,
    0.3267, 0.3252, 0.3246, 0.3230, 0.3200,
    0.3088, 0.3086, 0.3046, 0.2977, 0.2899,
    0.2890, 0.2854, 0.2846, 0.2841, 0.2808,
    0.2791, 0.2770, 0.2751, 0.2700, 0.2696,
    0.2655, 0.2632, 0.2629, 0.2556, 0.2536,
    0.2505, 0.2482, 0.2476, 0.2451, 0.2392
]

# Create the table
print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names, tfidf_values):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(tfidf_values, feature_names)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: far         3.7775
# Feature: long        2.9920
# Feature: away        1.9398
# Feature: soon        1.8843
# Feature: commonly    1.2162
# Feature: well        1.0854
# Feature: probably    1.0325
# Feature: perchance   0.9862
# Feature: generally   0.8986
# Feature: merely      0.8710
# Feature: forth       0.8680
# Feature: especially  0.7764
# Feature: hardly      0.7315
# Feature: frequently  0.7026
# Feature: ago         0.6940
# Feature: close       0.6887
# Feature: occasionally 0.6873
# Feature: forward     0.6737
# Feature: somewhat    0.6728
# Feature: near        0.6441
# Feature: surely      0.6268
# Feature: instead     0.6226
# Feature: suddenly    0.6014
# Feature: apparently  0.5990
# Feature: nearly      0.5915
# Feature: early       0.5860
# Feature: right       0.5581
# Feature: perfectly   0.5522
# Feature: easily      0.5484
# Feature: home        0.5314
# ...

# %%
# VERBS
# Define the feature names and TF-IDF values as lists
import matplotlib.pyplot as plt

# Define the feature names and TF-IDF values as lists
feature_names_verbs = [
    "come", "know", "think", "find", "hear",
    "look", "leave", "stand", "tell", "see",
    "grow", "let", "lie", "fall", "carry",
    "pass", "appear", "set", "begin", "turn",
    "live", "hold", "bear", "run", "sit",
    "bring", "speak", "eat", "walk", "cut",
    "ask", "read", "feel", "reach", "hang",
    "die", "follow", "draw", "mean", "use",
    "write", "lose", "send", "meet", "return",
    "wait", "rise", "sing", "want", "remain",
    "remember", "learn", "suppose", "seek", "add",
    "break", "stop", "throw", "observe", "prove",
    "believe", "need", "enter", "love", "try",
    "wish", "fill", "cross", "build", "expect",
    "consider", "kill", "answer", "describe", "start",
    "lead", "cover", "afford", "understand", "wear",
    "fly", "discover", "serve", "forget", "spread",
    "prepare", "gather", "belong", "recognize", "suggest",
    "proceed", "cast", "prefer", "strike", "receive",
    "talk", "continue", "raise", "remind", "settle"
]

tfidf_values_verbs = [
    2.7605, 2.4753, 2.3097, 2.2280, 1.9051,
    1.5776, 1.4804, 1.4801, 1.2121, 1.1806,
    1.1306, 1.1004, 1.0681, 0.9796, 0.9663,
    0.8859, 0.8053, 0.7984, 0.7701, 0.7533,
    0.7348, 0.7089, 0.7017, 0.6972, 0.6940,
    0.6699, 0.6655, 0.6631, 0.6417, 0.6400,
    0.6284, 0.6001, 0.5686, 0.5524, 0.5207,
    0.5195, 0.5051, 0.4857, 0.4739, 0.4723,
    0.4664, 0.4660, 0.4619, 0.4585, 0.4567,
    0.4480, 0.4347, 0.4337, 0.4184, 0.4167,
    0.4142, 0.4015, 0.4004, 0.3852, 0.3835,
    0.3825, 0.3772, 0.3769, 0.3741, 0.3671,
    0.3658, 0.3628, 0.3583, 0.3560, 0.3551,
    0.3549, 0.3427, 0.3342, 0.3310, 0.3297,
    0.3275, 0.3253, 0.3213, 0.3211, 0.3197,
    0.3179, 0.3142, 0.3100, 0.3100, 0.2999,
    0.2999, 0.2992, 0.2985, 0.2957, 0.2928,
    0.2798, 0.2746, 0.2720, 0.2690, 0.2641,
    0.2636, 0.2621, 0.2574, 0.2519, 0.2477,
    0.2455, 0.2451, 0.2436, 0.2424, 0.2419
]

# Create the table
print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names_verbs, tfidf_values_verbs):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names_verbs, tfidf_values_verbs)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: come        2.7605
# Feature: know        2.4753
# Feature: think       2.3097
# Feature: find        2.2280
# Feature: hear        1.9051
# Feature: look        1.5776
# Feature: leave       1.4804
# Feature: stand       1.4801
# Feature: tell        1.2121
# Feature: see         1.1806
# Feature: grow        1.1306
# Feature: let         1.1004
# Feature: lie         1.0681
# Feature: fall        0.9796
# Feature: carry       0.9663
# Feature: pass        0.8859
# Feature: appear      0.8053
# Feature: set         0.7984
# Feature: begin       0.7701
# Feature: turn        0.7533
# Feature: live        0.7348
# Feature: hold        0.7089
# Feature: bear        0.7017
# Feature: run         0.6972
# Feature: sit         0.6940
# Feature: bring       0.6699
# Feature: speak       0.6655
# Feature: eat         0.6631
# Feature: walk        0.6417
# Feature: cut         0.6400
# ...

# %%
# ADJECTIVES
# Define the feature names and TF-IDF values as lists
import matplotlib.pyplot as plt

# Define the feature names and TF-IDF values as lists
feature_names_adjectives = [
    "good", "great", "old", "little", "high",
    "wild", "long", "large", "new", "small",
    "indian", "white", "true", "young", "clear",
    "black", "dead", "present", "common", "low",
    "red", "brave", "short", "human", "strong",
    "distant", "fine", "open", "strange", "bright",
    "green", "beautiful", "deep", "sweet", "free",
    "perfect", "dark", "natural", "poor", "right",
    "moose", "certain", "wide", "broad", "bad",
    "dry", "general", "well", "early", "yellow",
    "fair", "hard", "fresh", "divine", "ready",
    "light", "wise", "rich", "half", "western",
    "particular", "english", "silent", "live", "simple",
    "rocky", "mere", "rare", "american", "noble",
    "sure", "blue", "pure", "wet", "usual",
    "narrow", "sharp", "smooth", "cold", "oblige",
    "real", "single", "native", "brown", "political",
    "second", "ancient", "vast", "ordinary", "main",
    "golden", "peculiar", "different", "close", "slight",
    "visible", "modern", "northern", "bare", "equal"
]

tfidf_values_adjectives = [
    2.7065, 2.3982, 1.9862, 1.6113, 1.4562,
    1.3155, 1.3026, 1.2649, 1.2135, 1.0805,
    1.0143, 0.9455, 0.7643, 0.7188, 0.7028,
    0.6753, 0.6668, 0.6544, 0.6512, 0.6423,
    0.6246, 0.6202, 0.5828, 0.5783, 0.5516,
    0.5474, 0.5392, 0.5275, 0.5242, 0.5222,
    0.5169, 0.5036, 0.4972, 0.4845, 0.4811,
    0.4796, 0.4692, 0.4546, 0.4335, 0.4241,
    0.4206, 0.4199, 0.4197, 0.4113, 0.4094,
    0.4093, 0.4084, 0.4045, 0.4039, 0.3867,
    0.3808, 0.3747, 0.3690, 0.3590, 0.3578,
    0.3555, 0.3519, 0.3509, 0.3445, 0.3443,
    0.3414, 0.3397, 0.3375, 0.3358, 0.3322,
    0.3296, 0.3286, 0.3263, 0.3235, 0.3227,
    0.3167, 0.3163, 0.3139, 0.3046, 0.3041,
    0.3024, 0.3007, 0.2990, 0.2965, 0.2914,
    0.2882, 0.2881, 0.2862, 0.2818, 0.2803,
    0.2802, 0.2773, 0.2744, 0.2739, 0.2737,
    0.2720, 0.2704, 0.2693, 0.2676, 0.2674,
    0.2672, 0.2647, 0.2620, 0.2619
]

# Create the table
print("{:<20} {:<15}".format("Feature", "TF-IDF Value"))
print("-" * 35)

for feature, tfidf in zip(feature_names_adjectives, tfidf_values_adjectives):
    print("{:<20} {:<15.4f}".format("Feature: " + feature, tfidf))

wordcloud_context_1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies({feature: tfidf for feature, tfidf in zip(feature_names_adjectives, tfidf_values_adjectives)})
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_context_1, interpolation='bilinear')
plt.title('Context 1 Word Cloud')
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Feature              TF-IDF Value
# -----------------------------------
# Feature: good        2.7065
# Feature: great       2.3982
# Feature: old         1.9862
# Feature: little      1.6113
# Feature: high        1.4562
# Feature: wild        1.3155
# Feature: long        1.3026
# Feature: large       1.2649
# Feature: new         1.2135
# Feature: small       1.0805
# Feature: indian      1.0143
# Feature: white       0.9455
# Feature: true        0.7643
# Feature: young       0.7188
# Feature: clear       0.7028
# Feature: black       0.6753
# Feature: dead        0.6668
# Feature: present     0.6544
# Feature: common      0.6512
# Feature: low         0.6423
# Feature: red         0.6246
# Feature: brave       0.6202
# Feature: short       0.5828
# Feature: human       0.5783
# Feature: strong      0.5516
# Feature: distant     0.5474
# Feature: fine        0.5392
# Feature: open        0.5275
# Feature: strange     0.5242
# Feature: bright      0.5222
# ...
