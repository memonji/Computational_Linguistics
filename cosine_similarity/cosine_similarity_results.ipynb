# %%
# American Gothic and Romanticism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.38079660904527346
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3257441199864121

# American Gothic and Dark Romanticism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.3074369365807541
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.31538513782414956

# American Gothic and Harlem Renaissance
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5493903714406114
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.13701163225761379

# American Gothic and Trascendentalism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.4983028141572356
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.36527570348752325

# American Gothic and Lost Generation
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5163156587634542
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3150019070336172

# American Gothic and Realism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.38079660904527346
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3257441199864121

# American Gothic and Naturalism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.4395375483874595
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3297018365515

# American Gothic and Slave Narratives
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5620055950317306
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.27615973540652566

# American Gothic and Experimentalism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.4053495951047737
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.26414754281190195

# %%
import matplotlib.pyplot as plt
from itertools import cycle


data = [
    {
        "Step": "American Gothic and Romanticism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.38079660904527346,
        "American Gothic and Romanticism": 0.3257441199864121
    },
    {
        "Step": "American Gothic and Dark Romanticism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.3074369365807541,
        "American Gothic and Dark Romanticism": 0.31538513782414956
    },
    {
        "Step": "American Gothic and Harlem Renaissance",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.5493903714406114,
        "American Gothic and Harlem Renaissance": 0.13701163225761379
    },
    {
        "Step": "American Gothic and Trascendentalism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.4983028141572356,
        "American Gothic and Trascendentalism": 0.36527570348752325
    },
    {
        "Step": "American Gothic and Lost Generation",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.5163156587634542,
        "American Gothic and Lost Generation": 0.3150019070336172
    },
    {
        "Step": "American Gothic and Realism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.38079660904527346,
        "American Gothic and Realism": 0.3257441199864121
    },
    {
        "Step": "American Gothic and Naturalism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.4395375483874595,
        "American Gothic and Naturalism": 0.3297018365515
    },
    {
        "Step": "American Gothic and Slave Narratives",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.5620055950317306,
        "American Gothic and Slave Narratives": 0.27615973540652566
    },
    {
        "Step": "American Gothic and Experimentalism",
        "Within document_set1": 0.4334894286793396,
        "Corpus inner similarity": 0.4053495951047737,
        "American Gothic and Experimentalism": 0.26414754281190195
    }
]

metrics = list(data[0].keys())[:2:]
colors = cycle(plt.cm.tab20.colors)
for metric in metrics:
    fig, ax = plt.subplots()
    for dataset in data:
        color = next(colors)
        ax.bar(dataset["Step"], dataset[metric], label=dataset["Step"], color=color)

    ax.set_xlabel('Datasets')
    ax.set_ylabel(metric)
    ax.set_title(f'Comparison of {metric} for Different Sets of Data')

    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
from itertools import cycle


data = [
    {
        "Step": "American Gothic and Romanticism",
        "Comparison between sets": 0.3257441199864121
    },
    {
        "Step": "American Gothic and Dark Romanticism",
        "Comparison between sets": 0.31538513782414956
    },
    {
        "Step": "American Gothic and Harlem Renaissance",
        "Comparison between sets": 0.13701163225761379
    },
    {
        "Step": "American Gothic and Trascendentalism",
        "Comparison between sets": 0.36527570348752325
    },
    {
        "Step": "American Gothic and Lost Generation",
        "Comparison between sets": 0.3150019070336172
    },
    {
        "Step": "American Gothic and Realism",
        "Comparison between sets": 0.3257441199864121
    },
    {
        "Step": "American Gothic and Naturalism",
        "Comparison between sets": 0.3297018365515
    },
    {
        "Step": "American Gothic and Slave Narratives",
        "Comparison between sets": 0.27615973540652566
    },
    {
        "Step": "American Gothic and Experimentalism",
        "Comparison between sets": 0.26414754281190195
    }
]

metrics = list(data[0].keys())[:2:]
colors = cycle(plt.cm.tab20.colors)
for metric in metrics:
    fig, ax = plt.subplots()
    for dataset in data:
        color = next(colors)
        ax.bar(dataset["Step"], dataset[metric], label=dataset["Step"], color=color)

    ax.set_xlabel('Datasets')
    # ax.set_ylabel(metric)
    ax.set_title(f'Comparison between datasets')

    plt.xticks(rotation=45, ha="right")
    # plt.tight_layout()
    plt.show()

# %%
# American Gothic is mostly similar to:
# - Romanticism
# - Dark Romanticism (American Romanticism)

# American Gothic is mostly different to:
# - Trascendentalism
# - Realism and Naturalism
# - Harlem Renaissance
# - Beat Generation

# %%
# SIMILARITIES

# %%
# American Gothic and Romanticism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.38079660904527346
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3257441199864121

# %%
# American Gothic and Dark Romanticism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.3074369365807541
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.31538513782414956

# %%
# Romanticism
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

data = np.array([
    [0.38534912, 0.40834425, 0.18808067, 0.42842721, 0.42842721, 0.44577139, 0.43140513, 0.18829975, 0.30564465, 0.39355662, 0.2756132,  0.48439006, 0.37595198, 0.36594859, 0.34115314, 0.38124052],
    [0.34222043, 0.37621435, 0.15727595, 0.36040546, 0.36040546, 0.40307474, 0.39227583, 0.21814683, 0.25638536, 0.35234916, 0.24210121, 0.42182204, 0.3609957,  0.30704732, 0.28991206, 0.32428641],
    [0.16659541, 0.19278634, 0.08799691, 0.19734619, 0.19734619, 0.20565997, 0.2117861,  0.13545724, 0.14567106, 0.20522342, 0.12767659, 0.22602683, 0.21786568, 0.15229126, 0.14180976, 0.14296659],
    [0.35782299, 0.38218339, 0.16459257, 0.37602855, 0.37602855, 0.39720113, 0.3990416,  0.20082196, 0.2638004,  0.35208082, 0.23899053, 0.42058857, 0.34657748, 0.32474783, 0.28921578, 0.33250022],
    [0.29406696, 0.3330493,  0.13338806, 0.310089,   0.310089,   0.35717121, 0.34550272, 0.22513446, 0.21854547, 0.32123707, 0.19808009, 0.39592434, 0.35859536, 0.25075398, 0.22248314, 0.24646252],
    [0.19046735, 0.23680886, 0.08657545, 0.20378715, 0.20378715, 0.22946813, 0.23914237, 0.15848166, 0.14209905, 0.21856361, 0.142866,   0.25477174, 0.23461786, 0.16271933, 0.14940517, 0.16795131],
])

# # Define labels for the matrices
# labels = ["American Gothic", "Slave Narratives", "Overall"]

# # Create subplots for each matrix
# fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# # Plot the heatmaps with aspect='auto'
# cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis', aspect='auto')
# cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis', aspect='auto')
# cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis', aspect='auto')

# # Set axis labels and title
# axes[0].set_title('American Gothic corpus')
# axes[1].set_title('Slave Narratives corpus')
# axes[2].set_title('American Gothic / Slave Narratives corpora')

# # Add a colorbar for each matrix
# fig.colorbar(cax_set1, ax=axes[0])
# fig.colorbar(cax_set2, ax=axes[1])
# fig.colorbar(cax_between, ax=axes[2])

# # Rotate x-axis labels for better readability
# plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
# plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
# plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# # Adjust spacing between subplots
# plt.tight_layout()

# # Show the plot
# plt.show()


plt.figure(figsize=(10, 8))
sns.heatmap(data, cmap='viridis', xticklabels=False, yticklabels=False)
plt.title('Cosine Similarity Matrix American Gothic/Romanticism')
plt.show()

# %%
# DIFFERENCES

# %%
# American Gothic and Harlem Renaissance
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5493903714406114
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.13701163225761379

import matplotlib.pyplot as plt
import numpy as np

cosine_similarity_matrix_set1 = np.array( [
    [1.         , 0.58405885, 0.19829679, 0.48330414, 0.48330414, 0.63504497, 0.54213219, 0.29224908, 0.27072996, 0.44622098, 0.29946055, 0.48741816, 0.42768254, 0.36221563, 0.31730091, 0.3336734 ],
    [0.58405885, 1.         , 0.24494836, 0.53822702, 0.53822702, 0.68402582, 0.61759227, 0.40424072, 0.30461867, 0.45883815, 0.31276605, 0.52485319, 0.45201328, 0.38366036, 0.33028277, 0.35721707],
    [0.19829679, 0.24494836, 1.         , 0.3727496 , 0.3727496 , 0.2793852 , 0.24134799, 0.13461479, 0.16134986, 0.20906484, 0.13819564, 0.23076437, 0.18724987, 0.19674092, 0.15464267, 0.23312179],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.63504497, 0.68402582, 0.2793852 , 0.6418324 , 0.6418324 , 1.         , 0.66831747, 0.41607   , 0.32125334, 0.51366403, 0.37173886, 0.59312701, 0.48010565, 0.44982796, 0.38529484, 0.39936052],
    [0.54213219, 0.61759227, 0.24134799, 0.5767327 , 0.5767327 , 0.66831747, 1.         , 0.38101324, 0.33828927, 0.46981518, 0.32370526, 0.5591378 , 0.48017528, 0.40645815, 0.37343809, 0.40214464],
    [0.29224908, 0.40424072, 0.13461479, 0.306338  , 0.306338  , 0.41607   , 0.38101324, 1.         , 0.1720375 , 0.23176413, 0.14593259, 0.28027979, 0.25542905, 0.19746438, 0.16380347, 0.17705567],
    [0.27072996, 0.30461867, 0.16134986, 0.31389891, 0.31389891, 0.32125334, 0.33828927, 0.1720375 , 1.         , 0.30132363, 0.19663675, 0.37691881, 0.29975451, 0.28959448, 0.26037327, 0.27974998],
    [0.44622098, 0.45883815, 0.20906484, 0.4716217 , 0.4716217 , 0.51366403, 0.46981518, 0.23176413, 0.30132363, 1.         , 0.43035599, 0.62532765, 0.62093506, 0.46382732, 0.43010087, 0.43422595],
    [0.29946055, 0.31276605, 0.13819564, 0.3236258 , 0.3236258 , 0.37173886, 0.32370526, 0.14593259, 0.19663675, 0.43035599, 1.         , 0.40770927, 0.41116798, 0.33236355, 0.35518551, 0.34089815],
    [0.48741816, 0.52485319, 0.23076437, 0.54487361, 0.54487361, 0.59312701, 0.5591378 , 0.28027979, 0.37691881, 0.62532765, 0.40770927, 1.         , 0.56477009, 0.51545999, 0.49318291, 0.51402007],
    [0.42768254, 0.45201328, 0.18724987, 0.43650459, 0.43650459, 0.48010565, 0.48017528, 0.25542905, 0.29975451, 0.62093506, 0.41116798, 0.56477009, 1.         , 0.39698919, 0.40434397, 0.41405508],
    [0.36221563, 0.38366036, 0.19674092, 0.43514856, 0.43514856, 0.44982796, 0.40645815, 0.19746438, 0.28959448, 0.46382732, 0.33236355, 0.51545999, 0.39698919, 1.         , 0.42932149, 0.4243699 ],
    [0.31730091, 0.33028277, 0.15464267, 0.37987825, 0.37987825, 0.38529484, 0.37343809, 0.16380347, 0.26037327, 0.43010087, 0.35518551, 0.49318291, 0.40434397, 0.42932149, 1.         , 0.65398757],
    [0.3336734 , 0.35721707, 0.23312179, 0.38775274, 0.38775274, 0.39936052, 0.40214464, 0.17705567, 0.27974998, 0.43422595, 0.34089815, 0.51402007, 0.41405508, 0.4243699 , 0.65398757, 1.        ]
])
cosine_similarity_matrix_set2 = np.array([
    [1.0, 0.39637508, 0.26298557, 0.11344499],
    [0.39637508, 1.0, 0.5409345, 0.30564776],
    [0.26298557, 0.5409345, 1.0, 0.77573507],
    [0.11344499, 0.30564776, 0.77573507, 1.0]
])

cosine_similarity_matrix_between = np.array([
    [0.12459125, 0.18179716, 0.12494223, 0.1385264],
    [0.14551368, 0.20199588, 0.14972849, 0.14992707],
    [0.06280232, 0.08145725, 0.05801914, 0.06034988],
    [0.14660105, 0.2076322, 0.15162229, 0.17081051],
    [0.14660105, 0.2076322, 0.15162229, 0.17081051],
    [0.15570463, 0.2037124, 0.13516052, 0.15654133],
    [0.17150513, 0.22197673, 0.14543654, 0.16858941],
    [0.06123943, 0.07896853, 0.06175854, 0.06239643],
    [0.11089951, 0.14257051, 0.08321951, 0.09621492],
    [0.13670588, 0.17886983, 0.11777019, 0.13321924],
    [0.09660864, 0.13860209, 0.09360044, 0.10930546],
    [0.16636375, 0.22229478, 0.14897651, 0.16624151],
    [0.13156317, 0.18148949, 0.11652595, 0.13592437],
    [0.1213547, 0.16967106, 0.11289988, 0.12916301],
    [0.11649382, 0.16631003, 0.1001529, 0.1248556],
    [0.12955021, 0.17928245, 0.11437658, 0.141696]
])
# Define labels for the matrices
labels = ["American Gothic", "Slave Narratives", "Overall"]

# Create subplots for each matrix
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps with aspect='auto'
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis', aspect='auto')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis', aspect='auto')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis', aspect='auto')

# Set axis labels and title
axes[0].set_title('American Gothic corpus')
axes[1].set_title('Harlem Renaissance corpus')
axes[2].set_title('American Gothic / Harlem Renaissance corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes
    [0.30100304, 0.36626719, 0.20338441, 0.32618465, 0.27704495, 0.18790381, 0.26947079, 0.11398177, 0.18354316, 0.26340861],
    [0.5195433 , 0.57209545, 0.38439236, 0.55687647, 0.47184904, 0.33870621, 0.46495911, 0.21643967, 0.29008912, 0.35442678],
    [0.33987133, 0.38786986, 0.30503032, 0.39226741, 0.38682726, 0.27178179, 0.32450327, 0.21432285, 0.19830631, 0.23726955],
    [0.56416383, 0.63938169, 0.42223819, 0.60034439, 0.52937522, 0.37212309, 0.49695506, 0.23088724, 0.33706741, 0.44452126],
    [0.49281146, 0.57885238, 0.36883291, 0.54001908, 0.4526973 , 0.32267287, 0.4282666 , 0.19929887, 0.30809163, 0.39275654],
    [0.42527181, 0.49459921, 0.33386003, 0.45858636, 0.4080499 , 0.2907575 , 0.3807167 , 0.1807783 , 0.22776878, 0.29240498],
    [0.38688178, 0.45820181, 0.28267036, 0.40377017, 0.37021814, 0.25306933, 0.34963136, 0.18428311, 0.21905764, 0.25442722],
    [0.40836442, 0.47477404, 0.28678063, 0.41975933, 0.37646214, 0.25940124, 0.36994876, 0.17821628, 0.21474954, 0.2900962 ]
])

# Define labels for the matrices
labels = ["American Gothic", "Trascendentalism", "Overall"]

# Create subplots for each matrix
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis')

# Set axis labels and title
# axes[0].set_xticks(np.arange(len(labels)))
# axes[0].set_yticks(np.arange(len(labels)))
# axes[0].set_xticklabels(labels)
# axes[0].set_yticklabels(labels)
axes[0].set_title('American Gothic corpus')

# axes[1].set_xticks(np.arange(len(labels)))
# axes[1].set_yticks(np.arange(len(labels)))
# axes[1].set_xticklabels(labels)
# axes[1].set_yticklabels(labels)
axes[1].set_title('Trascendentalism corpus')

# axes[2].set_xticks(np.arange(len(labels)))
# axes[2].set_yticks(np.arange(len(labels)))
# axes[2].set_xticklabels(labels)
# axes[2].set_yticklabels(labels)
axes[2].set_title('American Gothic / Trascendentalism corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# American Gothic and Lost Generation
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5163156587634542
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3150019070336172

import matplotlib.pyplot as plt
import numpy as np

cosine_similarity_matrix_set1 = np.array( [
    [1.         , 0.58405885, 0.19829679, 0.48330414, 0.48330414, 0.63504497, 0.54213219, 0.29224908, 0.27072996, 0.44622098, 0.29946055, 0.48741816, 0.42768254, 0.36221563, 0.31730091, 0.3336734 ],
    [0.58405885, 1.         , 0.24494836, 0.53822702, 0.53822702, 0.68402582, 0.61759227, 0.40424072, 0.30461867, 0.45883815, 0.31276605, 0.52485319, 0.45201328, 0.38366036, 0.33028277, 0.35721707],
    [0.19829679, 0.24494836, 1.         , 0.3727496 , 0.3727496 , 0.2793852 , 0.24134799, 0.13461479, 0.16134986, 0.20906484, 0.13819564, 0.23076437, 0.18724987, 0.19674092, 0.15464267, 0.23312179],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0
    [0.54966284, 0.48689489, 1.        , 0.62180228, 0.50808408, 0.58477075, 0.6581948,  0.55341751, 0.51066593, 0.29972289],
    [0.45714531, 0.39396412, 0.62180228, 1.        , 0.38605052, 0.46399553, 0.4749108,  0.43191263, 0.40956416, 0.22530892],
    [0.3195537,  0.4144102,  0.50808408, 0.38605052, 1.        , 0.64573681, 0.66797026, 0.55553258, 0.81770669, 0.25541012],
    [0.34854833, 0.53504201, 0.58477075, 0.46399553, 0.64573681, 1.        , 0.76576565, 0.63639935, 0.64911109, 0.32845359],
    [0.3694899,  0.46500442, 0.6581948,  0.4749108,  0.66797026, 0.76576565, 1.        , 0.70189363, 0.64310092, 0.35574695],
    [0.32514504, 0.41943917, 0.55341751, 0.43191263, 0.55553258, 0.63639935, 0.70189363, 1.        , 0.58114778, 0.28603344],
    [0.33340167, 0.41481133, 0.51066593, 0.40956416, 0.81770669, 0.64911109, 0.64310092, 0.58114778, 1.        , 0.26693897],
    [0.15760572, 0.20893861, 0.29972289, 0.22530892, 0.25541012, 0.32845359, 0.35574695, 0.28603344, 0.26693897, 1.        ]
])

cosine_similarity_matrix_between = np.array([
    [0.24434636, 0.25717877, 0.3195897,  0.26187756, 0.40518745, 0.4319635,  0.43041367, 0.363763,   0.41053243, 0.1657873 ],
    [0.21617613, 0.25204197, 0.32218583, 0.25466755, 0.42747673, 0.46113918, 0.47128966, 0.39746172, 0.43270729, 0.17962835],
    [0.09955218, 0.1107522,  0.14546693, 0.11368313, 0.19680386, 0.20579754, 0.22722824, 0.1763611,  0.20342676, 0.08087297],
    [0.2450177,  0.31614413, 0.38480218, 0.2981669,  0.48207288, 0.51760566, 0.55010633, 0.44144466, 0.47880861, 0.20995556],
    [0.2450177,  0.31614413, 0.38480218, 0.2981669,  0.48207288, 0.51760566, 0.55010633, 0.44144466, 0.47880861, 0.20995556],
    [0.25392018, 0.30506071, 0.37469576, 0.29813867, 0.50025444, 0.53115417, 0.54906639, 0.45974124, 0.50210589, 0.20335939],
    [0.25974719, 0.33568169, 0.3791419,  0.31098443, 0.4763808,  0.5279122,  0.53155821, 0.44063878, 0.47768829, 0.21450273],
    [0.08763432, 0.10605912, 0.14023655, 0.10703173, 0.1986099,  0.21844885, 0.23999869, 0.18228046, 0.20213825, 0.09070292],
    [0.15945171, 0.17874566, 0.21960883, 0.16763397, 0.28118774, 0.29768797, 0.32008842, 0.24236342, 0.28845545, 0.11910372],
    [0.23956701, 0.28911859, 0.32447971, 0.25360746, 0.39776086, 0.43042571, 0.43393732, 0.35949548, 0.40626857, 0.15969798]
])

# Define labels for the matrices
labels = ["American Gothic", "Lost Generation", "Overall"]

# Create subplots for each matrix
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis')

# Set axis labels and title
# axes[0].set_xticks(np.arange(len(labels)))
# axes[0].set_yticks(np.arange(len(labels)))
# axes[0].set_xticklabels(labels)
# axes[0].set_yticklabels(labels)
axes[0].set_title('American Gothic corpus')

# axes[1].set_xticks(np.arange(len(labels)))
# axes[1].set_yticks(np.arange(len(labels)))
# axes[1].set_xticklabels(labels)
# axes[1].set_yticklabels(labels)
axes[1].set_title('Lost Generation corpus')

# axes[2].set_xticks(np.arange(len(labels)))
# axes[2].set_yticks(np.arange(len(labels)))
# axes[2].set_xticklabels(labels)
# axes[2].set_yticklabels(labels)
axes[2].set_title('American Gothic / Lost Generation corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# American Gothic and Realism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.38079660904527346
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3257441199864121

# %%
# American Gothic and Naturalism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.4395375483874595
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.3297018365515

# %%
# NEUTRAL

# %%
# American Gothic and Slave Narratives
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5620055950317306
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.27615973540652566

import matplotlib.pyplot as plt
import numpy as np

cosine_similarity_matrix_set1 = np.array( [
    [1.         , 0.58405885, 0.19829679, 0.48330414, 0.48330414, 0.63504497, 0.54213219, 0.29224908, 0.27072996, 0.44622098, 0.29946055, 0.48741816, 0.42768254, 0.36221563, 0.31730091, 0.3336734 ],
    [0.58405885, 1.         , 0.24494836, 0.53822702, 0.53822702, 0.68402582, 0.61759227, 0.40424072, 0.30461867, 0.45883815, 0.31276605, 0.52485319, 0.45201328, 0.38366036, 0.33028277, 0.35721707],
    [0.19829679, 0.24494836, 1.         , 0.3727496 , 0.3727496 , 0.2793852 , 0.24134799, 0.13461479, 0.16134986, 0.20906484, 0.13819564, 0.23076437, 0.18724987, 0.19674092, 0.15464267, 0.23312179],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.63504497, 0.68402582, 0.2793852 , 0.6418324 , 0.6418324 , 1.         , 0.66831747, 0.41607   , 0.32125334, 0.51366403, 0.37173886, 0.59312701, 0.48010565, 0.44982796, 0.38529484, 0.39936052],
    [0.54213219, 0.61759227, 0.24134799, 0.5767327 , 0.5767327 , 0.66831747, 1.         , 0.38101324, 0.33828927, 0.46981518, 0.32370526, 0.5591378 , 0.48017528, 0.40645815, 0.37343809, 0.40214464],
    [0.29224908, 0.40424072, 0.13461479, 0.306338  , 0.306338  , 0.41607   , 0.38101324, 1.         , 0.1720375 , 0.23176413, 0.14593259, 0.28027979, 0.25542905, 0.19746438, 0.16380347, 0.17705567],
    [0.27072996, 0.30461867, 0.16134986, 0.31389891, 0.31389891, 0.32125334, 0.33828927, 0.1720375 , 1.         , 0.30132363, 0.19663675, 0.37691881, 0.29975451, 0.28959448, 0.26037327, 0.27974998],
    [0.44622098, 0.45883815, 0.20906484, 0.4716217 , 0.4716217 , 0.51366403, 0.46981518, 0.23176413, 0.30132363, 1.         , 0.43035599, 0.62532765, 0.62093506, 0.46382732, 0.43010087, 0.43422595],
    [0.29946055, 0.31276605, 0.13819564, 0.3236258 , 0.3236258 , 0.37173886, 0.32370526, 0.14593259, 0.19663675, 0.43035599, 1.         , 0.40770927, 0.41116798, 0.33236355, 0.35518551, 0.34089815],
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps with aspect='auto'
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis', aspect='auto')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis', aspect='auto')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis', aspect='auto')

# Set axis labels and title
axes[0].set_title('American Gothic corpus')
axes[1].set_title('Slave Narratives corpus')
axes[2].set_title('American Gothic / Slave Narratives corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# American Gothic and Slave Narratives
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.5620055950317306
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.27615973540652566

import matplotlib.pyplot as plt
import numpy as np

cosine_similarity_matrix_set1 = np.array( [
    [1.         , 0.58405885, 0.19829679, 0.48330414, 0.48330414, 0.63504497, 0.54213219, 0.29224908, 0.27072996, 0.44622098, 0.29946055, 0.48741816, 0.42768254, 0.36221563, 0.31730091, 0.3336734 ],
    [0.58405885, 1.         , 0.24494836, 0.53822702, 0.53822702, 0.68402582, 0.61759227, 0.40424072, 0.30461867, 0.45883815, 0.31276605, 0.52485319, 0.45201328, 0.38366036, 0.33028277, 0.35721707],
    [0.19829679, 0.24494836, 1.         , 0.3727496 , 0.3727496 , 0.2793852 , 0.24134799, 0.13461479, 0.16134986, 0.20906484, 0.13819564, 0.23076437, 0.18724987, 0.19674092, 0.15464267, 0.23312179],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.63504497, 0.68402582, 0.2793852 , 0.6418324 , 0.6418324 , 1.         , 0.66831747, 0.41607   , 0.32125334, 0.51366403, 0.37173886, 0.59312701, 0.48010565, 0.44982796, 0.38529484, 0.39936052],
    [0.54213219, 0.61759227, 0.24134799, 0.5767327 , 0.5767327 , 0.66831747, 1.         , 0.38101324, 0.33828927, 0.46981518, 0.32370526, 0.5591378 , 0.48017528, 0.40645815, 0.37343809, 0.40214464],
    [0.29224908, 0.40424072, 0.13461479, 0.306338  , 0.306338  , 0.41607   , 0.38101324, 1.         , 0.1720375 , 0.23176413, 0.14593259, 0.28027979, 0.25542905, 0.19746438, 0.16380347, 0.17705567],
    [0.27072996, 0.30461867, 0.16134986, 0.31389891, 0.31389891, 0.32125334, 0.33828927, 0.1720375 , 1.         , 0.30132363, 0.19663675, 0.37691881, 0.29975451, 0.28959448, 0.26037327, 0.27974998],
    [0.44622098, 0.45883815, 0.20906484, 0.4716217 , 0.4716217 , 0.51366403, 0.46981518, 0.23176413, 0.30132363, 1.         , 0.43035599, 0.62532765, 0.62093506, 0.46382732, 0.43010087, 0.43422595],
    [0.29946055, 0.31276605, 0.13819564, 0.3236258 , 0.3236258 , 0.37173886, 0.32370526, 0.14593259, 0.19663675, 0.43035599, 1.         , 0.40770927, 0.41116798, 0.33236355, 0.35518551, 0.34089815],
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps with aspect='auto'
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis', aspect='auto')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis', aspect='auto')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis', aspect='auto')

# Set axis labels and title
axes[0].set_title('American Gothic corpus')
axes[1].set_title('Slave Narratives corpus')
axes[2].set_title('American Gothic / Slave Narratives corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# American Gothic and Experimentalism
# Average Cosine Similarity Matrix within document_set1: 0.4334894286793396
# Average Cosine Similarity Matrix within document_set2: 0.4053495951047737
# Average Cosine Similarity Matrix between document_set1 and document_set2: 0.26414754281190195
import matplotlib.pyplot as plt
import numpy as np

cosine_similarity_matrix_set1 = np.array( [
    [1.         , 0.58405885, 0.19829679, 0.48330414, 0.48330414, 0.63504497, 0.54213219, 0.29224908, 0.27072996, 0.44622098, 0.29946055, 0.48741816, 0.42768254, 0.36221563, 0.31730091, 0.3336734 ],
    [0.58405885, 1.         , 0.24494836, 0.53822702, 0.53822702, 0.68402582, 0.61759227, 0.40424072, 0.30461867, 0.45883815, 0.31276605, 0.52485319, 0.45201328, 0.38366036, 0.33028277, 0.35721707],
    [0.19829679, 0.24494836, 1.         , 0.3727496 , 0.3727496 , 0.2793852 , 0.24134799, 0.13461479, 0.16134986, 0.20906484, 0.13819564, 0.23076437, 0.18724987, 0.19674092, 0.15464267, 0.23312179],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.48330414, 0.53822702, 0.3727496 , 1.         , 1.         , 0.6418324 , 0.5767327 , 0.306338  , 0.31389891, 0.4716217 , 0.3236258 , 0.54487361, 0.43650459, 0.43514856, 0.37987825, 0.38775274],
    [0.63504497, 0.68402582, 0.2793852 , 0.6418324 , 0.6418324 , 1.         , 0.66831747, 0.41607   , 0.32125334, 0.51366403, 0.37173886, 0.59312701, 0.48010565, 0.44982796, 0.38529484, 0.39936052],
    [0.54213219, 0.61759227, 0.24134799, 0.5767327 , 0.5767327 , 0.66831747, 1.         , 0.38101324, 0.33828927, 0.46981518, 0.32370526, 0.5591378 , 0.48017528, 0.40645815, 0.37343809, 0.40214464],
    [0.29224908, 0.40424072, 0.13461479, 0.306338  , 0.306338  , 0.41607   , 0.38101324, 1.         , 0.1720375 , 0.23176413, 0.14593259, 0.28027979, 0.25542905, 0.19746438, 0.16380347, 0.17705567],
    [0.27072996, 0.30461867, 0.16134986, 0.31389891, 0.31389891, 0.32125334, 0.33828927, 0.1720375 , 1.         , 0.30132363, 0.19663675, 0.37691881, 0.29975451, 0.28959448, 0.26037327, 0.27974998],
    [0.44622098, 0.45883815, 0.20906484, 0.4716217 , 0.4716217 , 0.51366403, 0.46981518, 0.23176413, 0.30132363, 1.         , 0.43035599, 0.62532765, 0.62093506, 0.46382732, 0.43010087, 0.43422595],
    [0.17019652, 0.26135855, 0.41877991, 0.51090759, 0.33137702, 1.        , 0.48689489, 0.39396412, 0.4144102 , 0.53504201, 0.46500442, 0.41943917, 0.41481133, 0.20893861],
    [0.16442839, 0.25991773, 0.17702123, 0.22132601, 0.54966284, 0.48689489, 1.        , 0.62180228, 0.50808408, 0.58477075, 0.6581948 , 0.55341751, 0.51066593, 0.29972289],
    [0.14557353, 0.22699925, 0.15440527, 0.18888901, 0.45714531, 0.39396412, 0.62180228, 1.        , 0.38605052, 0.46399553, 0.4749108 , 0.43191263, 0.40956416, 0.22530892],
    [0.35366365, 0.39534331, 0.27271114, 0.24133378, 0.3195537 , 0.4144102 , 0.50808408, 0.38605052, 1.        , 0.64573681, 0.66797026, 0.55553258, 0.81770669, 0.25541012],
    [0.21008357, 0.2832807 , 0.25930322, 0.36633814, 0.34854833, 0.53504201, 0.58477075, 0.46399553, 0.64573681, 1.        , 0.76576565, 0.63639935, 0.64911109, 0.32845359],
    [0.19412575, 0.27975085, 0.18479327, 0.24008105, 0.3694899 , 0.46500442, 0.6581948 , 0.4749108 , 0.66797026, 0.76576565, 1.        , 0.70189363, 0.64310092, 0.35574695],
    [0.17100606, 0.23607144, 0.28704263, 0.38554384, 0.32514504, 0.41943917, 0.55341751, 0.43191263, 0.55553258, 0.63639935, 0.70189363, 1.        , 0.58114778, 0.28603344],
    [0.36500426, 0.38711372, 0.28042433, 0.23521286, 0.33340167, 0.41481133, 0.51066593, 0.40956416, 0.81770669, 0.64911109, 0.64310092, 0.58114778, 1.        , 0.26693897],
    [0.07931667, 0.1335685 , 0.0886757 , 0.11655384, 0.15760572, 0.20893861, 0.29972289, 0.22530892, 0.25541012, 0.32845359, 0.35574695, 0.28603344, 0.26693897, 1.        ]
])


# Define labels for the matrices
labels = ["American Gothic", "Slave Narratives", "Overall"]

# Create subplots for each matrix
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed

# Plot the heatmaps
cax_set1 = axes[0].matshow(cosine_similarity_matrix_set1, cmap='viridis')
cax_set2 = axes[1].matshow(cosine_similarity_matrix_set2, cmap='viridis')
cax_between = axes[2].matshow(cosine_similarity_matrix_between, cmap='viridis')

# Set axis labels and title
# axes[0].set_xticks(np.arange(len(labels)))
# axes[0].set_yticks(np.arange(len(labels)))
# axes[0].set_xticklabels(labels)
# axes[0].set_yticklabels(labels)
axes[0].set_title('American Gothic corpus')

# axes[1].set_xticks(np.arange(len(labels)))
# axes[1].set_yticks(np.arange(len(labels)))
# axes[1].set_xticklabels(labels)
# axes[1].set_yticklabels(labels)
axes[1].set_title('Experimentalism corpus')

# axes[2].set_xticks(np.arange(len(labels)))
# axes[2].set_yticks(np.arange(len(labels)))
# axes[2].set_xticklabels(labels)
# axes[2].set_yticklabels(labels)
axes[2].set_title('American Gothic / Experimentalism corpora')

# Add a colorbar for each matrix
fig.colorbar(cax_set1, ax=axes[0])
fig.colorbar(cax_set2, ax=axes[1])
fig.colorbar(cax_between, ax=axes[2])

# Rotate x-axis labels for better readability
plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")
plt.setp(axes[2].get_xticklabels(), rotation=45, ha="right")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
